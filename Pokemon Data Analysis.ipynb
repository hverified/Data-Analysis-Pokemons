# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('ggplot')

# %matplotlib inline

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total Power'] = df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.groupby('Type 1').max()
# Out:
#             #                   Name   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug       666                Yanmega   86     185      230      135      230
# Dark      717               Zweilous  126     150      125      140      130
# Dragon    718       Zygarde50% Forme  125     180      130      180      150
# Electric  702              Zebstrika   90     123      115      165      110
# Fairy     716                Xerneas  126     131       95      131      154
# Fighting  701                Tyrogue  144     145       95      140      110
# Fire      721                 Vulpix  115     160      140      159      154
# Flying    715  TornadusTherian Forme   85     115       80      125       90
# Ghost     711                 Yamask  150     165      145      170      135
# Grass     673             Whimsicott  123     132      131      145      129
# Ground    645                Vibrava  115     180      160      150      120
# ...

# %%
df.sort_values('Type 1', ascending=False).max()
# Out:
# #                           721
# Name           Zygarde50% Forme
# Type 1                    Water
# HP                          255
# Attack                      190
# Defense                     230
# Sp. Atk                     194
# Sp. Def                     230
# Speed                       180
# Generation                    6
# Legendary                  True
# Total Power                 780
# dtype: object

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total Power
# 0       65     45           1      False          318
# 1       80     60           1      False          405
# 2      100     80           1      False          525
# 3      120     80           1      False          625
# 4       50     65           1      False          309

# %% [markdown]
# **Maximum HP**

# %%
df[df['HP']==df['HP'].max()]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary  Total Power
# 261     55           2      False          540

# %% [markdown]
# **Maximum Attack**

# %%
df[df['Attack']==df['Attack'].max()]
# Out:
#        #                 Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Power
# 163      154      100    130           1       True          780

# %% [markdown]
# **Maximum Defense**

# %%
df[df['Defense']==df['Defense'].max()]
# Out:
#        #                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230       55
# 230  213              Shuckle    Bug    Rock  20      10      230       10
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230       60
#
#      Sp. Def  Speed  Generation  Legendary  Total Power
# 224       95     30           2      False          610
# 230      230      5           2      False          505
# 333       80     50           3      False          630

# %% [markdown]
# **Fastest Speed**

# %%
df[df['Speed']==df['Speed'].max()]
# Out:
#        #               Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 431  386  DeoxysSpeed Forme  Psychic    NaN  50      95       90       95
#
#      Sp. Def  Speed  Generation  Legendary  Total Power
# 431       90    180           3       True          600

# %%
newdf = df.groupby('Type 1').mean().reset_index()

# %%
plt.figure(figsize=(9,4),dpi=120)
sns.set_context('paper')

sns.barplot(x='Type 1',y='HP',data = newdf, palette = 'viridis')
plt.tight_layout()
plt.title('HP vs Type')
HP = newdf['HP']

# %%
HP = newdf['HP']

# %%
plt.figure(figsize=(9,4), dpi = 150)
sns.set_context('paper')

sns.barplot(x='Type 1',y='Attack',data = newdf, palette = 'viridis')
plt.tight_layout()
plt.title('Attack vs Type')
# Out:
# Text(0.5, 1.0, 'Attack vs Type')

# %%
plt.figure(figsize=(9,4), dpi = 150)
sns.set_context('paper')

sns.barplot(x='Type 1',y='Sp. Atk',data = newdf, palette = 'viridis')
plt.tight_layout()
plt.title('Special Attack vs Type')
# Out:
# Text(0.5, 1.0, 'Special Attack vs Type')

# %%
plt.figure(figsize=(9,4), dpi = 150)
sns.set_context('paper')

sns.barplot(x='Type 1',y='Defense',data = newdf, palette = 'viridis')
plt.tight_layout()
plt.title('Defense vs Type')
# Out:
# Text(0.5, 1.0, 'Defense vs Type')

# %%
newdf.drop(['#','Generation','Legendary'], axis = 1, inplace=True)

# %%
newdf.head()
# Out:
#      Type 1         HP      Attack    Defense    Sp. Atk    Sp. Def  \
# 0       Bug  56.884058   70.971014  70.724638  53.869565  64.797101
# 1      Dark  66.806452   88.387097  70.225806  74.645161  69.516129
# 2    Dragon  83.312500  112.125000  86.375000  96.843750  88.843750
# 3  Electric  59.795455   69.090909  66.295455  90.022727  73.704545
# 4     Fairy  74.117647   61.529412  65.705882  78.529412  84.705882
#
#        Speed  Total Power
# 0  61.681159   378.927536
# 1  76.161290   445.741935
# 2  83.031250   550.531250
# 3  84.500000   443.409091
# 4  48.588235   413.176471

# %%
plt.figure(figsize=(9,4), dpi = 150)
sns.set_context('paper')

sns.barplot(x='Type 1',y='Total Power',data = newdf, palette = 'viridis')
plt.tight_layout()
plt.title('Total Power vs Type')
# Out:
# Text(0.5, 1.0, 'Total Power vs Type')

# %%
df.drop(['#'],axis = 1, inplace = True)

# %%
df.head(10)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                  Bulbasaur  Grass  Poison  45      49       49       65
# 1                    Ivysaur  Grass  Poison  60      62       63       80
# 2                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire     NaN  39      52       43       60
# 5                 Charmeleon   Fire     NaN  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 7  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total Power
# 0       65     45           1      False          318
# ...
